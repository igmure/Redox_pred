# %%
from utils.DatasetToCSVORedOx159 import DatasetToCSVORO159Class

# %%
# Path to the folder containing XYZ files
folder_path = "data/ORedOx159"

dataset_to_csv = DatasetToCSVORO159Class()
df = dataset_to_csv.process_files(folder_path)
df
# Out:
# Error converting XYZ to SMILES for file data/ORedOx159/4b-11_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-00_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-09_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-05_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-16_2c_rd.xyz: Valence of atom 0 is 4, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-08_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-04_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-01_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-07_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-06_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3e-00_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-04_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-03_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-02_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3b-02_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# !!! Warning !!! Distance between atoms 41 and 23 (0.959694 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 30 (0.959695 A) is suspicious.
# !!! Warning !!! Distance between atoms 21 and 19 (0.962811 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/4b-09_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-06_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-14_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-02_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-07_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-11_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-01_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-07_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-11_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-09_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-13_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-01_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-00_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-10_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-17_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-01_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-02_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-05_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-15_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-09_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-05_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-18_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-09_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-18_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-01_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-13_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-03_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-15_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-09_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-12_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-00_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-07_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-16_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/2d-07_2a_gn.xyz: Final molecular charge (-2) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3b-01_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3e-02_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3e-01_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-14_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-10_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-07_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-19_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-01_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-16_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-04_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# !!! Warning !!! Distance between atoms 23 and 22 (0.992469 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 24 (0.995336 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 26 (0.966942 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 31 (0.966942 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/4b-04_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-09_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-19_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-04_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-04_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3a-01_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-00_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3e-00_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3b-00_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-00_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-05_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-09_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-01_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-03_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-05_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-02_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# !!! Warning !!! Distance between atoms 41 and 23 (0.972251 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 30 (0.972251 A) is suspicious.
# !!! Warning !!! Distance between atoms 21 and 20 (0.959351 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 22 (0.959291 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/3f-09_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-01_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-06_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-06_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-05_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-05_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-03_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-03_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-10_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-00_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-11_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-04_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-04_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-13_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-08_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-17_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-04_2c_ox.xyz: Final molecular charge (2) does not match input (1); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-08_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-10_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-01_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-08_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-05_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-02_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/2b-02_1a_ox.xyz: Final molecular charge (-1) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-01_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-10_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-02_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-02_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-12_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-15_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-07_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-16_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-05_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-07_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3a-00_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3e-01_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-05_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-17_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-12_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-10_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-01_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-10_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# !!! Warning !!! Distance between atoms 41 and 23 (0.958221 A) is suspicious.
# !!! Warning !!! Distance between atoms 42 and 30 (0.958221 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 22 (0.998966 A) is suspicious.
# !!! Warning !!! Distance between atoms 25 and 24 (0.994258 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 29 (0.977565 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/3c-09_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-17_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-00_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-07_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-08_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-07_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-03_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-03_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-05_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-02_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-06_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-04_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-13_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-01_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-15_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3b-02_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-18_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-06_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-12_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-00_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-11_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-18_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-09_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-02_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-16_2c_gn.xyz: Valence of atom 0 is 4, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-11_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-01_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# !!! Warning !!! Distance between atoms 35 and 25 (0.959968 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 32 (0.959969 A) is suspicious.
# !!! Warning !!! Distance between atoms 21 and 19 (0.964665 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/3f-06_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-06_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-17_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-04_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-01_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-08_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-10_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-12_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# !!! Warning !!! Distance between atoms 35 and 25 (0.958156 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 32 (0.958155 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/2d-07_2a_ox.xyz: Final molecular charge (-2) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-01_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-00_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-10_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-02_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-08_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-10_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-02_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-11_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3b-01_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-07_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3a-00_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-08_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3e-00_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-05_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-03_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3e-02_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-02_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3e-02_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-12_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-03_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-02_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-04_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-01_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-04_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-00_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-03_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-00_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-05_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-02_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-02_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-03_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-08_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-08_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-04_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-07_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-15_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/2a-05_1a_ox.xyz: Final molecular charge (-1) does not match input (0); could not find valid bond ordering
# !!! Warning !!! Distance between atoms 32 and 29 (0.958352 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/3c-03_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-00_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3b-01_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-00_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-14_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-01_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-13_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-01_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-05_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-03_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-05_2c_gn.xyz: Pre-condition Violation
# 	Atomic number not found
# 	Violation occurred on line 177 in file Code/GraphMol/PeriodicTable.h
# 	Failed Expression: atomicNumber < byanum.size()
# 	RDKIT: 2024.03.6
# 	BOOST: 1_85
# !!! Warning !!! Distance between atoms 33 and 26 (0.969313 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 31 (0.969314 A) is suspicious.
# !!! Warning !!! Distance between atoms 21 and 20 (0.959552 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 22 (0.959550 A) is suspicious.
# [19:13:34]
#
# ****
# Pre-condition Violation
# Atomic number not found
# Violation occurred on line 177 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/PeriodicTable.h
# Failed Expression: atomicNumber < byanum.size()
# ----------
# Stacktrace:
# ----------
# ****
#
# !!! Warning !!! Distance between atoms 35 and 25 (0.972718 A) is suspicious.
# !!! Warning !!! Distance between atoms 36 and 32 (0.972718 A) is suspicious.
# !!! Warning !!! Distance between atoms 33 and 26 (0.975557 A) is suspicious.
# !!! Warning !!! Distance between atoms 34 and 31 (0.975557 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/4c-04_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-06_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-00_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-00_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-05_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-02_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-14_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-05_2c_rd.xyz: Pre-condition Violation
# 	Atomic number not found
# 	Violation occurred on line 177 in file Code/GraphMol/PeriodicTable.h
# 	Failed Expression: atomicNumber < byanum.size()
# 	RDKIT: 2024.03.6
# 	BOOST: 1_85
#
# Error converting XYZ to SMILES for file data/ORedOx159/4d-04_2c_gn.xyz: Final molecular charge (2) does not match input (1); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-07_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-02_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-02_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# [19:13:34]
#
# ****
# Pre-condition Violation
# Atomic number not found
# Violation occurred on line 177 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/PeriodicTable.h
# Failed Expression: atomicNumber < byanum.size()
# ----------
# Stacktrace:
# ----------
# ****
# Error converting XYZ to SMILES for file data/ORedOx159/4d-06_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-07_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-03_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/2a-05_1a_gn.xyz: Final molecular charge (-1) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-03_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-15_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-00_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-09_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4d-06_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-07_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-06_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/2b-02_1a_rd.xyz: Final molecular charge (-1) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-01_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-04_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-08_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4b-10_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3e-01_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-05_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-08_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-09_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-02_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-09_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-14_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/2d-07_2a_rd.xyz: Final molecular charge (-2) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-01_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3b-02_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/2a-05_1a_rd.xyz: Final molecular charge (-1) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-03_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-04_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3a-00_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3a-01_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3b-00_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-11_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-13_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3d-00_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-03_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-01_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# !!! Warning !!! Distance between atoms 21 and 20 (0.960189 A) is suspicious.
# !!! Warning !!! Distance between atoms 23 and 22 (0.960175 A) is suspicious.
# Error converting XYZ to SMILES for file data/ORedOx159/3c-18_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-18_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3d-03_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-08_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-05_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4c-02_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-03_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-05_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-10_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-06_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-03_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-17_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-14_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-11_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/2b-02_1a_gn.xyz: Final molecular charge (-1) does not match input (0); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-04_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-08_2c_ox.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3c-06_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-07_2c_rd.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-16_2c_ox.xyz: Valence of atom 0 is 4, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3f-04_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/3b-00_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4b-06_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-19_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4a-08_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4c-00_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/4d-04_2c_rd.xyz: Final molecular charge (2) does not match input (1); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3c-05_2c_ox.xyz: Pre-condition Violation
# 	Atomic number not found
# 	Violation occurred on line 177 in file Code/GraphMol/PeriodicTable.h
# 	Failed Expression: atomicNumber < byanum.size()
# 	RDKIT: 2024.03.6
# 	BOOST: 1_85
#
# Error converting XYZ to SMILES for file data/ORedOx159/4b-02_2c_gn.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3f-09_2c_gn.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/ORedOx159/4a-03_2c_ox.xyz: Final molecular charge (2) does not match input (3); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/ORedOx159/3a-01_2c_rd.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# !!! Warning !!! Distance between atoms 21 and 19 (0.967522 A) is suspicious.
# !!! Warning !!! Distance between atoms 32 and 29 (0.959923 A) is suspicious.
# [19:13:35]
#
# ****
# Pre-condition Violation
# Atomic number not found
# Violation occurred on line 177 in file /project/build/temp.linux-x86_64-cpython-310/rdkit/Code/GraphMol/PeriodicTable.h
# Failed Expression: atomicNumber < byanum.size()
# ----------
# Stacktrace:
# ----------
# ****
#     Family System  NumAtoms  \
# 0       2c     03        35
# 1       2a     06        21
# 2       2b     00        29
# 3       4b     11        30
# 4       4b     00        40
# ..     ...    ...       ...
# 154     2d     03        22
# 155     2c     05        39
# 156     2a     05        21
# 157     3c     05        27
# 158     3f     03        31
#
#                                                 SMILES  charge_gn  \
# 0               CC1=CC(=O)c2c(c(-c3ccccc3)n(C)c2C)C1=O          0
# 1                           O=C1C=CC(=O)c2cc(CBr)ccc21          0
# 2    [H]/[O+]=C1/C=C(S(=O)(=O)[O-])/C(=[O+]/[H])c2c...         -1
# 3                                                 None          2
# 4                                                 None          2
# ..                                                 ...        ...
# 154        O=C1C(Cl)=CC(=C2C=C(Cl)C(=O)C(Cl)=C2)C=C1Cl          0
# 155         CCOC(=O)c1c2c(c3n1CCC3)C(=O)C(C)=C(OC)C2=O          0
# 156                                               None         -1
# 157                                               None          2
# 158                                               None          2
#
#             E_gn         G_gn         E_ox         G_ox         E_rd  \
# 0    -861.367098  -861.132207  -861.094439  -860.860387  -861.415401
# 1   -3147.242958 -3147.131136 -3146.909515 -3146.800103 -3147.320427
# 2   -1461.720899 -1461.571330 -1461.551369 -1461.404473 -1461.699574
# 3    -758.454934  -758.262018  -757.827504  -757.639013  -758.812965
# 4    -731.337408  -731.032784  -730.759118  -730.460909  -731.644353
# ..           ...          ...          ...          ...          ...
# 154 -2449.866358 -2449.782791 -2449.560437 -2449.479118 -2449.992248
# 155 -1050.019670 -1049.759062 -1049.730758 -1049.472619 -1050.078080
# 156 -1157.795177 -1157.698793 -1157.622668 -1157.528724 -1157.754409
# 157  -665.093771  -664.911941  -664.473300  -664.295045  -665.455262
# 158 -1147.862065 -1147.646947 -1147.268077 -1147.057347 -1148.199514
#
#             G_rd    dG_red     dG_ox
# 0    -861.183181 -0.915758  1.136604
# 1   -3147.210774 -0.944422  1.195817
# 2   -1461.553440 -0.846894  1.031641
# 3    -758.623278 -1.226044  1.487789
# 4    -731.343406 -1.175406  1.436659
# ..           ...       ...       ...
# 154 -2449.911230 -0.993223  1.168457
# 155 -1049.821087 -0.926809  1.151227
# 156 -1157.660251 -0.826242  1.034853
# 157  -665.276220 -1.229063  1.481680
# 158 -1147.987698 -1.205535  1.454384
#
# [159 rows x 13 columns]

# %%
# Save DataFrames to CSV files
df.to_csv("data/ORedOx159.csv", index=False)

print("DataFrames saved:")
print(f"{len(df)} records")
# Out:
# DataFrames saved:
# 159 records

# %%
from utils.DatasetToCSVROP313 import DatasetToCSVROP313Class

# %%
# Path to the folder containing XYZ files
folder_path = "data/rop313/orop"

dataset_to_csv = DatasetToCSVROP313Class()
df = dataset_to_csv.process_files(folder_path)
df
# Out:
# Error converting XYZ to SMILES for file data/rop313/orop/182/1.b973c.xyz: Valence of atom 0 is 2, which is larger than the allowed maximum, 3
# Error converting XYZ to SMILES for file data/rop313/orop/191/1.b973c.xyz: Final molecular charge (-1) does not match input (-10); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/rop313/orop/180/1.b973c.xyz: Valence of atom 11 is 3, which is larger than the allowed maximum, 1
# Error converting XYZ to SMILES for file data/rop313/orop/87/1.b973c.xyz: Final molecular charge (0) does not match input (-1); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/rop313/orop/192/1.b973c.xyz: Valence of atom 0 is 3, which is larger than the allowed maximum, 4
# Error converting XYZ to SMILES for file data/rop313/orop/128/1.b973c.xyz: Final molecular charge (0) does not match input (-1); could not find valid bond ordering
# Error converting XYZ to SMILES for file data/rop313/orop/178/1.b973c.xyz: Valence of atom 11 is 3, which is larger than the allowed maximum, 1
#     system_number  dG_red       Solvent  Charge_gn  Charge_rd  UHF_gn  UHF_rd  \
# 0              49    1.41  acetonitrile          1          0       1       0
# 1             181   -1.10  acetonitrile          0         -1       0       1
# 2              52    1.69  acetonitrile          1          0       1       0
# 3              27    1.73  acetonitrile          1          0       1       0
# 4             139    1.67  acetonitrile          1          0       1       0
# ..            ...     ...           ...        ...        ...     ...     ...
# 188            18    1.60  acetonitrile          1          0       1       0
# 189            62    2.50  acetonitrile          1          0       1       0
# 190           129    1.95  acetonitrile          1          0       1       0
# 191            59    1.51  acetonitrile          1          0       1       0
# 192             3    1.84  acetonitrile          1          0       1       0
#
#                                               SMILES_1  NumAtoms_1
# 0                                          COc1ccccc1O          17
# 1    O=C(O)c1ccccc1-c1c2cc(Br)c(=O)c(Br)c-2oc2c(Br)...          37
# 2                                        Oc1ccc(Br)cc1          13
# 3                                     CC=Cc1ccc(Cl)cc1          19
# 4                                C(=Nc1ccccc1)c1ccccc1          25
# ..                                                 ...         ...
# 188                                   CC=Cc1cccc(OC)c1          23
# 189                                           C1COCCO1          14
# 190                                     O=Cc1ccc(O)cc1          15
# 191                                          C1=COCCC1          14
# 192                              C(#Cc1ccccc1)c1ccccc1          24
#
# [193 rows x 9 columns]

# %%
# Save DataFrames to CSV files
df.to_csv("data/OROP.csv", index=False)

print("DataFrames saved:")
print(f"{len(df)} records")
# Out:
# DataFrames saved:
# 193 records

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# Define the SMILES string
smiles_string = "	CN(C)C1=CC2SC3=CC(=CC=C3N=C2C=C1)N(C)C"

# Convert the SMILES string to a molecule
mol = Chem.MolFromSmiles(smiles_string)

# Draw the molecule and display the image
img = Draw.MolToImage(mol)
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
'''
how to calculate smiles from xyz file in rdkit
'''
from rdkit.Chem import  MolToSmiles, rdDetermineBonds, Draw, MolFromXYZFile, Mol, RemoveHs
raw_mol = MolFromXYZFile('data/jp0c05052_si_002/rop313/orop/49/1.b973c.xyz')
mol = Mol(raw_mol)
rdDetermineBonds.DetermineBonds(mol, charge=0)
mol_no_h = RemoveHs(mol)
smi = MolToSmiles(mol_no_h, canonical=True, isomericSmiles=False)
print("SMILES:", smi)
img = Draw.MolToImage(mol_no_h)
img.show()
# Out:
# SMILES: COc1ccccc1O
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
